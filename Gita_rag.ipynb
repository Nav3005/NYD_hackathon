# %% [markdown]
# # Code Clash

# %% [markdown]
# ## Gita_RAG

# %% [markdown]
# ### Step 1 : Data Extraction and Collection

# %% [markdown]
# This script demonstrates loading multiple CSV files into pandas DataFrames.
#
# Files Loaded:
# 1. Bhagwad_Gita_Verses_English_Questions.csv
#    - Contains Bhagavad Gita verses in English with related questions.
#    - Stored in `df`.
#
# 2. Bhagwad_Gita_Verses_Concepts.csv
#    - Contains concepts associated with the verses.
#    - Stored in `df1`.
#
# 3. Bhagwad_Gita_Verses_English.csv
#    - Contains the English translation of Bhagavad Gita verses.
#    - Stored in `df2`.
#
# 4. Gita_Word_Meanings_English.csv
#    - Contains the English meanings of Sanskrit words from the Gita.
#    - Stored in `df3`.
#
# 5. Gita_Word_Meanings_Hindi.csv
#    - Contains the Hindi meanings of Sanskrit words from the Gita.
#    - Stored in `df4`.
#
# Steps:
# 1. Import the pandas library.
# 2. Define the file paths for each CSV file.
# 3. Load each file into a pandas DataFrame using `pd.read_csv()`.
#
# Variables:
# - `df`, `df1`, `df2`, `df3`, `df4`: DataFrames storing the loaded data.
#
# Use Cases:
# - Preparing data for analysis, visualization, or machine learning tasks.
# - Merging and processing related datasets for insights.
#
# Note:
# - Ensure the file paths are accurate and the files exist in the specified location.

# %%
import pandas as pd

file_path = "Bhagwad_Gita_Verses_English_Questions.csv" # Loading data from csv file and storing it in a dataframe
df = pd.read_csv(file_path)

file_path1 = "Bhagwad_Gita_Verses_Concepts.csv"
df1 = pd.read_csv(file_path1)

file_path2 = "Bhagwad_Gita_Verses_English.csv"
df2 = pd.read_csv(file_path2)

file_path3 = "Gita_Word_Meanings_English.csv"
df3 = pd.read_csv(file_path3)

file_path4 = "Gita_Word_Meanings_Hindi.csv"
df4 = pd.read_csv(file_path4)

# %%
#df
#df1
#df2
#df3
#df4

# %% [markdown]
#  ### Step 2 : Data Formating

# %% [markdown]
# This script demonstrates how to use LlamaIndex's `SimpleDirectoryReader` with a custom file extractor
# to process multiple CSV files efficiently.
#
# Modules Used:
# - SimpleDirectoryReader: Reads and processes files from specified paths.
# - PagedCSVReader: A specialized reader for handling CSV files, suitable for large datasets.
#
# Steps:
# 1. **Import Required Libraries**:
#     - Import the `SimpleDirectoryReader` for reading files.
#     - Import the `PagedCSVReader` for efficient CSV file handling.
#
# 2. **Initialize CSV Reader**:
#     - Create an instance of `PagedCSVReader` to process `.csv` files.
#
# 3. **Setup SimpleDirectoryReader**:
#     - Pass a list of file paths (`input_files`) to the reader.
#     - Map `.csv` files to the `PagedCSVReader` via the `file_extractor` argument.
#
# 4. **Load Data**:
#     - Use `load_data()` to process all specified files.
#     - The output is stored in the `docs` variable.
#
# Variables:
# - `file_path1, file_path2, ...`: Paths to the input CSV files.
# - `csv_reader`: An instance of `PagedCSVReader` for processing CSV files.
# - `reader`: An instance of `SimpleDirectoryReader` configured to read CSV files.
# - `docs`: A list of processed documents ready for downstream tasks.
#
# Use Cases:
# - Efficiently loading and processing multiple CSV files for embedding, querying, or analytics.

# %%
# Necessary Modules from llama_index
from llama_index.core.readers import SimpleDirectoryReader # used to read and extract data from files of different formats such as csv
from llama_index.readers.file import PagedCSVReader # used to read data from csv files

csv_reader = PagedCSVReader()

reader = SimpleDirectoryReader( 
    input_files=[file_path1,file_path2,file_path3,file_path4],
    file_extractor= {".csv": csv_reader}
    )

docs = reader.load_data()

# %%
docs # Displaying the data extracted from the files as a dictionary
# Out:
# [Document(id_='6929c48a-8e02-40af-9eab-1d81581e4a2b', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 13\nConcept: Transmigration of Soul\nKeyword: Transmigration\nSanskrit: देहिनोऽस्मिन्यथा देहे कौमारं यौवनं जरा| तथा देहान्तरप्राप्तिर्धीरस्तत्र न मुह्यति || 2.13 ||\nEnglish: Just as childhood, youth, and old age are natural stages for a living being in their current body, so too is the attainment of a new body. Therefore, a wise person is not deceived.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d4da2257-6012-4f6f-9be9-847fe77fec24', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 14\nConcept: Impermanance of pleasure and pain\nKeyword: Transience\nSanskrit: मात्रास्पर्शास्तु कौन्तेय शीतोष्णसुखदुःखदाः| आगमापायिनोऽनित्यास्तांस्तितिक्षस्व भारत || 2.14 ||\nEnglish: The sensations of cold and heat, pleasure and pain, are a result of the interaction between our sense organs and external objects. However, these experiences are impermanent and will come to an end. Oh, descendant of Bharata, accept them without attachment.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b9635aa1-d54c-46f6-9ef2-52fd511f0bc9', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 22\nConcept: Transmigration of Soul\nKeyword: Transmigration\nSanskrit: वासांसि जीर्णानि यथा विहाय नवानि गृह्णाति नरोऽपराणि| तथा शरीराणि विहाय जीर्णा- न्यन्यानि संयाति नवानि देही || 2.22 ||\nEnglish: Just as a person discards old and tattered clothes and replaces them with new ones, similarly, after leaving behind an old and worn-out body, the embodied soul associates with a new body.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ebb1101a-bbfe-40a8-8afd-0752aae63d1d', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 25\nConcept: Characteristics of Soul\nKeyword: Soul\nSanskrit: अव्यक्तोऽयमचिन्त्योऽयमविकार्योऽयमुच्यते| तस्मादेवं विदित्वैनं नानुशोचितुमर्हसि || 2.25 ||\nEnglish: It is said that "This" is imperceptible, unimaginable, and immutable. Thus, having understood "This" in this way, one should not experience sorrow.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='37c6a0a3-7aac-4d78-99bb-160e9e21cc6a', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 27\nConcept: Cycle of Birth and Death\nKeyword: Transmigration\nSanskrit: जातस्य हि ध्रुवो मृत्युर्ध्रुवं जन्म मृतस्य च| तस्मादपरिहार्येऽर्थे न त्वं शोचितुमर्हसि || 2.27 ||\nEnglish: The demise of every being born into this world is inescapable, and rebirth after death is equally predetermined. Thus, there is no need to lament over an unavoidable truth.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='37757360-7b94-45c8-a68a-0e62ff649d15', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 48\nConcept: Equanimity\nKeyword: Equanimity\nSanskrit: योगस्थः कुरु कर्माणि सङ्गं त्यक्त्वा धनञ्जय| सिद्ध्यसिद्ध्योः समो भूत्वा समत्वं योग उच्यते || 2.48 ||\nEnglish: O Dhananjaya (Arjuna), by immersing yourself in Yoga, perform your actions with equanimity, relinquishing attachment and remaining steady in success and failure. This state of equanimity is known as Yoga.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4f0a6eb5-2ca0-4244-9867-4c4a67a82d24', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 55\nConcept: Equanimity\nKeyword: Equanimity\nSanskrit: प्रजहाति यदा कामान् सर्वान् पार्थ मनोगतान्| आत्मन्येवात्मना तुष्टः स्थितप्रज्ञस्तदोच्यते || 2.55 ||\nEnglish: The Lord said- Partha, when an individual completely gives up all desires that have entered the mind and finds contentment solely in the Self, through the Self, that person is known as one with unwavering wisdom.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d693ecde-d6ba-4c66-8db3-2d6c13a3d7d2', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 56\nConcept: Equanimity\nKeyword: Equanimity\nSanskrit: दुःखेष्वनुद्विग्नमनाः सुखेषु विगतस्पृहः| वीतरागभयक्रोधः स्थितधीर्मुनिरुच्यते || 2.56 ||\nEnglish: The person who remains steadfast in the face of misery, is uninterested in worldly pleasures, and is free from attachment, fear, and anger is known as a wise sage with unwavering wisdom.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f81e840c-7c3f-4dbe-ae50-a5d44a623bce', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 58\nConcept: Sense Control\nKeyword: Self-restraint\nSanskrit: यदा संहरते चायं कूर्मोऽङ्गानीव सर्वशः| इन्द्रियाणीन्द्रियार्थेभ्यस्तस्य प्रज्ञा प्रतिष्ठिता || 2.58 ||\nEnglish: When an individual completely disengages from their senses from the objects of the senses, like a tortoise that disengages its limbs into its shell, their wisdom becomes firmly rooted.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='905a7121-7b4d-46a0-912c-80053679d654', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 61\nConcept: Sense control\nKeyword: Self-restraint\nSanskrit: तानि सर्वाणि संयम्य युक्त आसीत मत्परः| वशे हि यस्येन्द्रियाणि तस्य प्रज्ञा प्रतिष्ठिता || 2.61 ||\nEnglish: By controlling all of the senses, one should remain focused on Me as the absolute. The wisdom of an individual whose senses are under check becomes unwavering.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='5c68c071-50d1-4401-ae84-5849c1020a31', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 62\nConcept: Detachment\nKeyword: Detachment\nSanskrit: ध्यायतो विषयान्पुंसः सङ्गस्तेषूपजायते| सङ्गात् संजायते कामः कामात्क्रोधोऽभिजायते || 2.62 ||\nEnglish: When an individual constantly thinks on objects, attachment to those objects arises. From this attachment, desire grows and from desire, anger arises.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1a577950-8073-4ab0-9ea5-0c8e913e2784', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 2\nVerse: 63\nConcept: Anger, Delusion\nKeyword: Agitation\nSanskrit: क्रोधाद्भवति संमोहः संमोहात्स्मृतिविभ्रमः| स्मृतिभ्रंशाद् बुद्धिनाशो बुद्धिनाशात्प्रणश्यति || 2.63 ||\nEnglish: Anger leads to delusion, which in turn results in the loss of memory. The loss of memory causes the loss of one's discriminative abilities, and without proper discrimination, one's downfall is certain.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='27b7638b-e364-41c4-a1c1-28bc6f0cbe7a', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 64\nConcept: Equanimity, Sense control\nKeyword: Equanimity\nSanskrit: रागद्वेषवियुक्तैस्तु विषयानिन्द्रियैश्चरन्| आत्मवश्यैर्विधेयात्मा प्रसादमधिगच्छति || 2.64 ||\nEnglish: The self-controlled person achieves tranquility by perceiving objects with senses that are free from attraction and repulsion, and are under his own control.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d0ef6491-60d4-4061-a80a-b6462d7c4a00', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 2\nVerse: 71\nConcept: Peace\nKeyword: Peace\nSanskrit: विहाय कामान्यः सर्वान्पुमांश्चरति निःस्पृहः| निर्ममो निरहंकारः स शांतिमधिगच्छति || 2.71 ||\nEnglish: The individual who rejects all desires and moves without any attachment or sense of ownership, and without any arrogance, attains true inner peace.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d729de82-241a-4b8b-98da-92c606b49f22', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 3\nVerse: 8\nConcept: Importance of performing duty\nKeyword: Duty\nSanskrit: नियतं कुरु कर्म त्वं कर्म ज्यायो ह्यकर्मणः| शरीरयात्रापि च ते न प्रसिद्ध्येदकर्मणः || 3.8 ||\nEnglish: Perform one's essential duties, because action is superior to inaction. Even the sustenance of one's body is impossible through inaction.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='bc0a5935-b3f9-4697-a746-5671b5ac7a00', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 3\nVerse: 19\nConcept: Detachment\nKeyword: Detachment\nSanskrit: तस्मादसक्तः सततं कार्यं कर्म समाचर| असक्तो ह्याचरन्कर्म परमाप्नोति पूरुषः || 3.19 ||\nEnglish: Therefore, it is important to be detached and consistently fulfill one's obligatory duty, because by doing so without attachment, one can attain the Highest state.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f2d45945-b0ce-485e-aa4d-140f0b3ecc53', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 3\nVerse: 37\nConcept: Cause of Sin, Rajas, Anger\nKeyword: Gunas\nSanskrit: काम एष क्रोध एष रजोगुणसमुद्भवः| महाशनो महापाप्मा विद्ध्येनमिह वैरिणम् || 3.37 ||\nEnglish: Recognize desire and anger, which arise from the quality of rajas, as great destroyers and great sins. They should be considered as the enemy within.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='beea8410-965d-4c0c-919a-27d0a41fcc5a', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 3\nVerse: 38\nConcept: Ignorance\nKeyword: Ignorance\nSanskrit: धूमेनाव्रियते वह्निर्यथाऽऽदर्शो मलेन च| यथोल्बेनावृतो गर्भस्तथा तेनेदमावृतम् || 3.38 ||\nEnglish: Just as fire is covered by smoke, a mirror is obscured by dirt, and a foetus is enclosed in the womb, similarly the true nature of the self is covered by that.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a8a02430-8f35-420b-a9bc-a6498578714c', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 3\nVerse: 39\nConcept: Ignorance\nKeyword: Ignorance\nSanskrit: आवृतं ज्ञानमेतेन ज्ञानिनो नित्यवैरिणा| कामरूपेण कौन्तेय दुष्पूरेणानलेन च || 3.39 ||\nEnglish: Desire, O son of Kunti, is an unquenchable fire that constantly obstructs the wise from attaining knowledge.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='09928287-d323-48f2-81ee-7ee9392bf1a4', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 4\nVerse: 6\nConcept: God's Incarnation (Avatar)\nKeyword: Incarnation\nSanskrit: अजोऽपि सन्नव्ययात्मा भूतानामीश्वरोऽपि सन्| प्रकृतिं स्वामधिष्ठाय संभवाम्यात्ममायया || 4.6 ||\nEnglish: Even though I am naturally birthless and imperishable, as the Lord of all beings, by controlling My Prakriti, I manifest Myself through My own Maya.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='cbe582df-ad92-4851-a634-5d3499b74589', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 4\nVerse: 7\nConcept: God's Incarnation (Avatar)\nKeyword: Incarnation\nSanskrit: यदा यदा हि धर्मस्य ग्लानिर्भवति भारत| अभ्युत्थानमधर्मस्य तदाऽऽत्मानं सृजाम्यहम् || 4.7 ||\nEnglish: Whenever there is a decline in virtue and an increase in vice, I reveal Myself, O descendant of the Bharata dynasty.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c55678b1-6e3d-4fdd-9fd3-51582a84c487', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 4\nVerse: 8\nConcept: God's Incarnation (Avatar)\nKeyword: Incarnation\nSanskrit: परित्राणाय साधूनां विनाशाय च दुष्कृताम्| धर्मसंस्थापनार्थाय संभवामि युगे युगे || 4.8 ||\nEnglish: In order to safeguard the righteous, vanquish the wicked, and establish righteousness, I appear in every era.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='206f56e4-4405-491a-a70b-75b7884c8a47', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 4\nVerse: 36\nConcept: Salvation for sinners\nKeyword: Salvation\nSanskrit: अपि चेदसि पापेभ्यः सर्वेभ्यः पापकृत्तमः| सर्वं ज्ञानप्लवेनैव वृजिनं सन्तरिष्यसि || 4.36 ||\nEnglish: Even if you are considered the greatest sinner among all sinners, you can still overcome all wickedness solely through the raft of Knowledge.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b443c1ad-99bf-4490-a331-242ca49fb0ca', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 4\nVerse: 39\nConcept: Faith and Peace\nKeyword: Peace\nSanskrit: श्रद्धावाँल्लभते ज्ञानं तत्परः संयतेन्द्रियः| ज्ञानं लब्ध्वा परां शान्तिमचिरेणाधिगच्छति || 4.39 ||\nEnglish: One who possesses faith, is diligent, and exercises self-control can attain Knowledge, and with the attainment of Knowledge, one can soon reach the state of supreme Peace.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='0fa9e5de-430b-4b3f-bfbc-54b832a57e3d', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 5\nVerse: 2\nConcept: Superiority of Karma Yoga\nKeyword: Karma\nSanskrit: संन्यासः कर्मयोगश्च निःश्रेयसकरावुभौ| तयोस्तु कर्मसंन्यासात्कर्मयोगो विशिष्यते || 5.2 ||\nEnglish: Both renunciation of actions and Karma-yoga can lead to Liberation, but Karma-yoga surpasses renunciation of actions.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='312d7405-6a26-4176-ac95-53e994738253', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="Chapter: 5\nVerse: 12\nConcept: Faith and Peace\nKeyword: Peace\nSanskrit: युक्तः कर्मफलं त्यक्त्वा शान्तिमाप्नोति नैष्ठिकीम्| अयुक्तः कामकारेण फले सक्तो निबध्यते || 5.12 ||\nEnglish: By firmly placing one's faith and becoming determined to relinquish the fruits of one's labor, one can attain the Peace that arises from steadfastness. However, a person who lacks resolute faith and is driven by desire to attain the results of their actions becomes bound.", mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='53bd11e3-14b7-4779-afd1-42a47eb0b27d', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 5\nVerse: 21\nConcept: Equanimity\nKeyword: Equanimity\nSanskrit: बाह्यस्पर्शेष्वसक्तात्मा विन्दत्यात्मनि यत्सुखम्| स ब्रह्मयोगयुक्तात्मा सुखमक्षयमश्नुते || 5.21 ||\nEnglish: By detaching oneself from external objects, one can experience the bliss that exists within the Self. By focusing the mind on meditation of Brahman, one can attain the eternal Bliss that never fades away.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='90a7c61b-aa74-4ede-bf38-7a9da6611676', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 5\nVerse: 22\nConcept: Cause of Sorrow\nKeyword: Sorrow\nSanskrit: ये हि संस्पर्शजा भोगा दुःखयोनय एव ते| आद्यन्तवन्तः कौन्तेय न तेषु रमते बुधः || 5.22 ||\nEnglish: As pleasures derived from contact with external objects are fleeting and ultimately result in sorrow, a wise individual, O son of Kunti, does not take pleasure in them.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1fc1aedc-a6d4-4f0f-bfdf-fe930c57c297', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 5\nVerse: 23\nConcept: Definition of Yogi\nKeyword: Yogi\nSanskrit: शक्नोतीहैव यः सोढुं प्राक्शरीरविमोक्षणात्| कामक्रोधोद्भवं वेगं स युक्तः स सुखी नरः || 5.23 ||\nEnglish: A person who is able to resist the urges of desire and anger even while still in their physical body is a true yogi, and such a person experiences true happiness.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c45a88de-1a24-480f-8b41-de333c790193', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 5\nVerse: 26\nConcept: Salvation\nKeyword: Salvation\nSanskrit: कामक्रोधवियुक्तानां यतीनां यतचेतसाम्| अभितो ब्रह्मनिर्वाणं वर्तते विदितात्मनाम् || 5.26 ||\nEnglish: For ascetics who have achieved self-control, conquered desire and anger, and attained realization of the Self, the state of absolute freedom or salvation is present in all directions.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7757d4da-d064-44c0-a4f9-82a842601c45', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 11\nConcept: Physical Preparation for Meditation\nKeyword: Meditation\nSanskrit: शुचौ देशे प्रतिष्ठाप्य स्थिरमासनमात्मनः| नात्युच्छ्रितं नातिनीचं चैलाजिनकुशोत्तरम् || 6.11 ||\nEnglish: To ensure a suitable seat for meditation, one should firmly establish in a clean location that is neither too high nor too low. The seat can be made of cloth, skin, and kusa-grass, arranged in succession from bottom to top.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='015a655f-e91b-49ff-b1c0-ac16c41eceb5', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 13\nConcept: Meditation Posture\nKeyword: Meditation\nSanskrit: समं कायशिरोग्रीवं धारयन्नचलं स्थिरः| संप्रेक्ष्य नासिकाग्रं स्वं दिशश्चानवलोकयन् || 6.13 ||\nEnglish: To maintain a steady posture and gaze during meditation, one should keep the body, head, and neck upright and motionless, fix their gaze at the tip of their nose, and avoid looking around.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='02d99b98-fe8a-4bcf-9089-04a33c55d18b', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 14\nConcept: Mental Preparation for Meditation\nKeyword: Meditation\nSanskrit: प्रशान्तात्मा विगतभीर्ब्रह्मचारिव्रते स्थितः| मनः संयम्य मच्चित्तो युक्त आसीत मत्परः || 6.14 ||\nEnglish: In order to control the mind through concentration and ultimately attain the supreme Goal of being united with Me, one must remain seated with a calm and peaceful mind, free from fear, and committed to celibacy.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fe50d61a-bb72-4f79-85b4-7e78394e1b41', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 15\nConcept: Reward of Meditation\nKeyword: Meditation\nSanskrit: युञ्जन्नेवं सदाऽऽत्मानं योगी नियतमानसः| शान्तिं निर्वाणपरमां मत्संस्थामधिगच्छति || 6.15 ||\nEnglish: By constantly concentrating the mind in this manner, the yogi who has attained control over their thoughts can attain the ultimate state of Peace that leads to Liberation, and this state of Peace resides within Me.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='88c185a6-89e0-4782-bfa5-2c331a074a06', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 16\nConcept: Importance of Moderation\nKeyword: Moderation\nSanskrit: नात्यश्नतस्तु योगोऽस्ति न चैकान्तमनश्नतः| न चातिस्वप्नशीलस्य जाग्रतो नैव चार्जुन || 6.16 ||\nEnglish: O Arjuna, please be aware that yoga is not suitable for those who eat excessively or abstain from food altogether, nor is it meant for individuals who tend to oversleep or remain awake for prolonged periods.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='092e0efd-2656-40ac-8b1e-a5feee083de1', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 17\nConcept: Importance of Moderation\nKeyword: Moderation\nSanskrit: युक्ताहारविहारस्य युक्तचेष्टस्य कर्मसु| युक्तस्वप्नावबोधस्य योगो भवति दुःखहा || 6.17 ||\nEnglish: For those who regulate their eating and movements, maintain moderate effort in their work, and practice temperance in sleep and wakefulness, yoga can serve as a means of dispelling sorrow.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='07c6a0d9-da8c-4e6c-9740-df653f31dfd5', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 19\nConcept: Attributes of Meditative Mind\nKeyword: Meditation\nSanskrit: यथा दीपो निवातस्थो नेङ्गते सोपमा स्मृता| योगिनो यतचित्तस्य युञ्जतो योगमात्मनः || 6.19 ||\nEnglish: A yogi who has achieved control over their mind and is focused on the Self can be likened to a lamp that remains steady without flickering when placed in a windless area.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a136e56f-f1a9-4cab-b2a8-9cfce2b949f1', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 22\nConcept: Equanimity\nKeyword: Equanimity\nSanskrit: यं लब्ध्वा चापरं लाभं मन्यते नाधिकं ततः| यस्मिन्स्थितो न दुःखेन गुरुणापि विचाल्यते || 6.22 ||\nEnglish: Acquiring something that one considers to be unparalleled and being firmly established in it, such that even profound sadness does not disturb one.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4cb47ec9-1248-4a61-8a14-f61bca2fca41', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 6\nVerse: 26\nConcept: Mental Preparation for Meditation\nKeyword: Meditation\nSanskrit: यतो यतो निश्चरति मनश्चञ्चलमस्थिरम्| ततस्ततो नियम्यैतदात्मन्येव वशं नयेत् || 6.26 ||\nEnglish: The yogi ought to control their mind by preventing it from being distracted by any causes that lead to its restlessness and instability, thereby subjecting it to the authority of the Self.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='efd75011-ba11-4f69-bb81-ea735d6f49ce', embedding=None, metadata={'file_path': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_name': 'Bhagwad_Gita_Verses_Concepts.csv', 'file_type': 'text/csv', 'file_size': 33660, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 7\nVerse: 4\nConcept: Physical Nature (Prakriti)\nKeyword: Prakriti\nSanskrit: भूमिरापोऽनलो वायुः खं मनो बुद्धिरेव च| अहङ्कार इतीयं मे भिन्ना प्रकृतिरष्टधा || 7.4 ||\nEnglish: My Prakrti is divided into eight parts: earth, water, fire, air, space, mind, intellect, and ego.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
# ...
#  Document(id_='ecdb1a18-02d4-4ff9-8be6-e1408f593bf4', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 12\nSanskrit Word: dadhmau\nEnglish Meaning: blew', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='42bee8e3-4ebb-4deb-a2d3-20bf5844e015', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 12\nSanskrit Word: pratāpa\nEnglish Meaning: vān', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='598a07ab-844a-411d-9d65-d81ec56c1cb0', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: tataḥ\nEnglish Meaning: thereafter', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fd83214f-8288-4eef-8f9e-788874a91cab', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: śhaṅkhāḥ\nEnglish Meaning: conches', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='338f1700-cd8d-4712-82b6-ce0e06a0394d', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: cha\nEnglish Meaning: and', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='b6b2f5e3-f6be-47eb-a148-b4d4d34e015c', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: bheryaḥ\nEnglish Meaning: bugles', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='122b85de-d240-4592-9095-a22bc0bafc8d', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: cha\nEnglish Meaning: and', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ef508f8b-8bc6-47d9-93c1-b31302120188', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: paṇava\nEnglish Meaning: ānaka', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='19dcb974-6eee-4397-95cb-223bbf65768b', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: go\nEnglish Meaning: mukhāḥ', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='581abd61-5ce9-4741-ae84-dac638b82f1e', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: sahasā\nEnglish Meaning: suddenly', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='1eaefe82-7e3a-4ef0-935e-9e57774fe73b', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: eva\nEnglish Meaning: indeed', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='e561b66a-9b01-4a74-bd09-8c4ca0c2d6cf', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: abhyahanyanta\nEnglish Meaning: blared forth', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='488dd383-877f-4545-b280-9cff1b0ef31b', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: saḥ\nEnglish Meaning: that', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='bdc623cd-fbcd-4c2d-8be9-6679586480ac', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: śhabdaḥ\nEnglish Meaning: sound', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7edba00f-2cf4-457a-a67f-2d0e28f39875', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: tumulaḥ\nEnglish Meaning: overwhelming', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='3e37d985-43b3-442b-b8f1-50e13aff61c2', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 13\nSanskrit Word: abhavat\nEnglish Meaning: was', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='30e2a7d3-d083-481c-a9b0-d3d3d031af75', embedding=None, metadata={'file_path': 'Gita_Word_Meanings_English.csv', 'file_name': 'Gita_Word_Meanings_English.csv', 'file_type': 'text/csv', 'file_size': 276930, 'creation_date': '2024-12-27', 'last_modified_date': '2024-12-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Chapter: 1\nShloka: 14\nSanskrit Word: tataḥ\nEnglish Meaning: then', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  ...]

# %% [markdown]
# ### RAG Pipeline

# %% [markdown]
# #### Step 3 : Creation of vector store

# %% [markdown]
# Script for Loading and Indexing Bhagavad Gita Verses with LlamaIndex and Chroma
#
# This script demonstrates the process of loading and indexing Bhagavad Gita verses using LlamaIndex for embedding and Chroma for vector storage.
#
# Files Loaded:
# 1. **Embedding Model**:
#    - A Hugging Face model used for embedding Bhagavad Gita verses into vector representations.
#    - Stored in `embed_model`.
#
# 2. **Chroma Database**:
#    - A persistent database used for storing vector embeddings.
#    - Stored in `db` and `db2`.
#
# 3. **Chroma Collection - "Verse_collection"**:
#    - Contains the embeddings of Bhagavad Gita verses stored in the Chroma database.
#    - Stored in `chroma_collection`.
#
# 4. **Index**:
#    - A vector index created using the embedded Bhagavad Gita verses.
#    - Stored in `index`.
#
# Steps:
# 1. **Import Required Libraries**:
#    - Import necessary libraries like `HuggingFaceEmbedding` from LlamaIndex, `chromadb`, and others for vector storage and indexing.
#
# 2. **Initialize Embedding Model**:
#    - Load the Hugging Face model for embedding text using `HuggingFaceEmbedding()`.
#
# 3. **Create Chroma Database Client**:
#    - Set up a persistent Chroma client to store vectors on disk using `chromadb.PersistentClient`.
#
# 4. **Create and Configure Chroma Collection**:
#    - Retrieve or create the `Verse_collection` where the vectors will be stored.
#
# 5. **Create Vector Store**:
#    - Use `ChromaVectorStore` to interface with the Chroma collection, and create a `StorageContext` to manage storage configurations.
#
# 6. **Create Index from Documents**:
#    - Create an index from the Bhagavad Gita verses using `VectorStoreIndex.from_documents()` with the embedded data.
#
# 7. **Load the Index from Disk**:
#    - Reinitialize the Chroma client and vector store to load the saved index from disk for further use.
#
# Variables:
# - **embed_model**: The Hugging Face model used for generating vector embeddings from text.
# - **db** and **db2**: Persistent Chroma clients storing the vector database.
# - **chroma_collection**: The Chroma collection containing stored embeddings.
# - **vector_store**: The Chroma vector store object used for managing and querying the embeddings.
# - **storage_context**: A context object for configuring how the embeddings are stored.
# - **index**: The vector index created from the embeddings of the Bhagavad Gita verses.
#
# Use Cases:
# - **Text Embedding and Storage**: Transforming textual data (Bhagavad Gita verses) into vector embeddings and storing them in a persistent database.
# - **Search and Querying**: Creating a searchable index for efficiently querying the Bhagavad Gita verses based on semantic similarity.
# - **Data Analysis**: Preparing the dataset for analysis, machine learning, or deep learning tasks, such as similarity comparison, clustering, or topic modeling.

# %%
# Creating HuggingFaceEmbedding object to use the HuggingFace model for embeddings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
embed_model = HuggingFaceEmbedding()

# %%
# Creating a VectorStore object to store the embeddings of the data
import chromadb
from llama_index.core import VectorStoreIndex
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext

# %%
# create client
db = chromadb.PersistentClient(path="./gita_db")
chroma_collection = db.get_or_create_collection("Verse_collection")

# %%
# save embedding to disk
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
# create index
index = VectorStoreIndex.from_documents(
    docs, storage_context=storage_context, embed_model=embed_model
)

# %%
# load from disk
db2 = chromadb.PersistentClient(path="./gita_db")
chroma_collection = db2.get_or_create_collection("Verse_collection")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
index = VectorStoreIndex.from_vector_store(
    vector_store,
    embed_model=embed_model,
)

# %% [markdown]
# #### Step 4 : Model Integration

# %% [markdown]
# Script for Querying the Bhagavad Gita Index Using Ollama LLM
#
# This script demonstrates how to query a persisted index of Bhagavad Gita verses using the Ollama language model for natural language processing.
#
# Files and Variables:
# 1. **Ollama LLM (Language Model)**:
#    - An instance of the `Ollama` language model used for processing and generating responses to queries.
#    - Stored in `llm`.
#
# 2. **Persisted Index**:
#    - The index created from Bhagavad Gita verses, stored using LlamaIndex and Chroma.
#    - Stored in `index`.
#
# 3. **Query Engine**:
#    - A query engine built using the index and the Ollama model for retrieving answers to user queries.
#    - Stored in `query_engine`.
#
# 4. **Query**:
#    - The user input query, such as "How does Gita start?" that is passed to the query engine.
#    - Input from the user and processed by the query engine.
#
# 5. **Response**:
#    - The response generated by the query engine based on the user's query.
#    - Stored in `response`.
#
# Steps:
# 1. **Import the Ollama LLM**:
#    - Import the `Ollama` language model from LlamaIndex's `llms.ollama`.
#
# 2. **Initialize Ollama LLM**:
#    - Create an instance of the `Ollama` model with the version `"llama3.2"`. This model will be used to process queries and generate responses.
#
# 3. **Create a Query Engine**:
#    - Create a `RetrieverQueryEngine` using the `index` (created in the previous script) and the `Ollama` language model (`llm`). This query engine will allow querying the indexed data.
#
# 4. **Query the Index**:
#    - Prompt the user to enter a query using `input()`.
#    - Pass the query to the query engine using `query_engine.query()` to retrieve a response based on the index.
#
# 5. **Print the Response**:
#    - Print the response returned by the `query_engine` to the user. The response will be the model's generated answer to the user's query.

# %%
from llama_index.llms.ollama import Ollama
llm = Ollama(model="llama3.2")
# Query Data from the persisted index
query_engine = index.as_query_engine(llm=llm) # RetrieverQueryEngine
response = query_engine.query(input("Enter your query: ")) # Query : "How does Gita start?"
print(response) # CompletionResponse
# Out:
# The Bhagwad Gita begins with Dhritarashtra's inquiry to Sanjaya about the assembly of his people and the sons of Pandu on the holy plain of Kurukshetra.
